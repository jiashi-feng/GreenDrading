# %%
import pandas as pd

# %%
try:
    original_data = pd.read_csv("西安市住宿服务数据.csv", encoding='gbk')
except UnicodeDecodeError:
    original_data = pd.read_csv("西安市住宿服务数据.csv", encoding='gb18030')

# %%
original_data.head()
# Out:
#                                      id pname   pcode cityname  citycode  \
# 0  b351fec2-3158-30a1-bbb6-ad2cbb22db20   陕西省  610000      西安市        29
# 1  c9932572-5b66-38b6-8823-f128833421ad   陕西省  610000      西安市        29
# 2  eae158e0-a045-39c6-9381-7b76de6399c1   陕西省  610000      西安市        29
# 3  3fd1d380-31c2-3911-8699-38d442b71473   陕西省  610000      西安市        29
# 4  092bcdeb-1370-3b39-82e4-8e9eeccced7e   陕西省  610000      西安市        29
#
#   adname  adcode                name                     address  \
# 0    新城区  610102         我见民宿(新民街分店)  新民街109号(北大街地铁站C1东南口步行470米)
# 1    新城区  610102    小王的民宿(钟鼓楼回民街1号店)     尚朴路13号(钟楼地铁站D东北口步行340米)
# 2    新城区  610102              一朵假日酒店   新时代广场A2栋(钟楼地铁站D东北口步行150米)
# 3    新城区  610102     西安会长大的幸福公寓(4号店)     西一路街道北大街同济北坊6号中建·世纪领域A座
# 4    新城区  610102  智逸美居民宿(钟鼓楼回民街20号店)             通济北坊与新民街交叉口西80米
#
#                location  ... business_area bigType midType smallType typecode  \
# ...

# %%
original_data.sample(10)
# Out:
#                                          id pname   pcode cityname  citycode  \
# 17620  192627f3-9193-3fca-b8d3-6be8fd88bee4   陕西省  610000      西安市        29
# 16912  d5459bdc-ba6b-39fc-ad17-384fe8626585   陕西省  610000      西安市        29
# 15612  1fb4425a-2e5b-3903-9c49-5909d348b571   陕西省  610000      西安市        29
# 12422  1a078d58-fbbc-3053-bcff-95d5d1807824   陕西省  610000      西安市        29
# 25714  df221063-c8a9-3dcf-9ef0-22beea4ff44c   陕西省  610000      西安市        29
# 12630  da929cf5-b757-3338-aefb-ad91f9d087ea   陕西省  610000      西安市        29
# 27059  dd005f27-1d34-3b1a-9065-05b2eae62f3e   陕西省  610000      西安市        29
# 12054  3c88342b-152f-3fe8-a599-79566d7f6b26   陕西省  610000      西安市        29
# 14109  6e75f0c1-fda6-306c-8ef7-15b2d935e05b   陕西省  610000      西安市        29
# 2951   df7b9e4e-453b-3967-b280-128c836b82e3   陕西省  610000      西安市        29
#
#       adname  adcode                    name                   address  \
# ...

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31588 entries, 0 to 31587
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             31588 non-null  object
#  1   pname          31588 non-null  object
#  2   pcode          31588 non-null  int64
#  3   cityname       31588 non-null  object
#  4   citycode       31588 non-null  int64
#  5   adname         31588 non-null  object
#  6   adcode         31588 non-null  int64
#  7   name           31588 non-null  object
#  8   address        31588 non-null  object
#  9   location       31588 non-null  object
#  10  tel            31588 non-null  object
#  11  business_area  31588 non-null  object
#  12  bigType        31588 non-null  object
#  13  midType        31588 non-null  object
#  14  smallType      31588 non-null  object
#  15  typecode       31588 non-null  object
#  16  timestamp      31588 non-null  object
# ...

# %%
original_data['timestamp'] = pd.to_datetime(original_data['timestamp'], format='%Y/%m/%d %H:%M')

# %%
original_data['typecode'] = original_data['typecode'].astype('category')

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31588 entries, 0 to 31587
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             31588 non-null  object
#  1   pname          31588 non-null  object
#  2   pcode          31588 non-null  int64
#  3   cityname       31588 non-null  object
#  4   citycode       31588 non-null  int64
#  5   adname         31588 non-null  object
#  6   adcode         31588 non-null  int64
#  7   name           31588 non-null  object
#  8   address        31588 non-null  object
#  9   location       31588 non-null  object
#  10  tel            31588 non-null  object
#  11  business_area  31588 non-null  object
#  12  bigType        31588 non-null  object
#  13  midType        31588 non-null  object
#  14  smallType      31588 non-null  object
#  15  typecode       31588 non-null  category
#  16  timestamp      31588 non-null  datetime64[ns]
# ...

# %%
# 检查名称和地址是否重复（可能为连锁分店）
name_address_dup = original_data.duplicated(subset=['name', 'address'], keep=False)
